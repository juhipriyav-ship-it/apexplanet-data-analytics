# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine, text

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\notebooks

# %%
import os

print(os.listdir())
# Out:
# ['task1.ipynb', 'task2_sql.ipynb']

# %%
print(os.listdir("../"))
# Out:
# ['.gitignore', 'apexplanet-data-analytics', 'dashboards', 'data', 'notebooks', 'README.md', 'reports', 'scripts', 'sql']

# %%
print(os.listdir("../data"))
# Out:
# ['cleaned_superstore.csv', 'SampleSuperstore.csv', 'superstore.db']

# %%
import os

print("Current notebook folder:")
print(os.getcwd())

print("\nFiles and folders here:")
print(os.listdir())
# Out:
# Current notebook folder:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\notebooks
#
# Files and folders here:
# ['task1.ipynb', 'task2_sql.ipynb']

# %%
import os

for root, dirs, files in os.walk(".."):
    for file in files:
        if file.lower() == "sample - superstore.csv":
            print("FOUND:")
            print(os.path.abspath(os.path.join(root, file)))

# %%
import os

for drive in ["C:\\", "D:\\"]:
    if os.path.exists(drive):
        for root, dirs, files in os.walk(drive):
            for file in files:
                if file.lower() == "sample - superstore.csv":
                    print(os.path.join(root, file))
# Out:
# C:\Users\juhip\OneDrive\Desktop\python folder\apexplanet-data-analytics\data\Sample - Superstore.csv

# %%
import os

print(os.getcwd())

data_path = os.path.abspath("../data")

print("\nData folder:")
print(data_path)

if os.path.exists(data_path):
    print("\nFiles in data folder:")
    print(os.listdir(data_path))
else:
    print("\nData folder does not exist.")
# Out:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\notebooks
#
# Data folder:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\data
#
# Files in data folder:
# ['cleaned_superstore.csv', 'SampleSuperstore.csv', 'superstore.db']

# %%
import os

print("Current location:")
print(os.getcwd())

print("\nParent folder contents:")
parent = os.path.abspath("..")
print(parent)
print(os.listdir(parent))

print("\nProject folder contents:")
project = os.path.abspath("../..")
print(project)
print(os.listdir(project))
# Out:
# Current location:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\notebooks
#
# Parent folder contents:
# c:\Users\juhip\Downloads\task-1\apexplanet-data-analytics
# ['.gitignore', 'apexplanet-data-analytics', 'dashboards', 'data', 'notebooks', 'README.md', 'reports', 'scripts', 'sql']
#
# Project folder contents:
# c:\Users\juhip\Downloads\task-1
# ['.git', 'apexplanet-data-analytics', 'dashboards', 'data', 'notebooks', 'README.md', 'reports', 'scripts']

# %%
import os

username_folder = os.path.expanduser("~")

for root, dirs, files in os.walk(username_folder):
    for file in files:
        if file.lower() == "sample - superstore.csv":
            print("FOUND:")
            print(os.path.join(root, file))
# Out:
# FOUND:
# C:\Users\juhip\OneDrive\Desktop\python folder\apexplanet-data-analytics\data\Sample - Superstore.csv

# %%
import os

home = os.path.expanduser("~")

matches = []

for root, dirs, files in os.walk(home):
    for file in files:
        if "superstore" in file.lower():
            matches.append(os.path.join(root, file))

print("Files found:")
for path in matches:
    print(path)
# Out:
# Files found:
# C:\Users\juhip\Downloads\README\apexplanet-data-analytics\data\cleaned_superstore.csv
# C:\Users\juhip\Downloads\README\apexplanet-data-analytics\data\SampleSuperstore.csv
# C:\Users\juhip\Downloads\README\apexplanet-data-analytics\data\superstore.db
# C:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\data\cleaned_superstore.csv
# C:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\data\SampleSuperstore.csv
# C:\Users\juhip\Downloads\task-1\apexplanet-data-analytics\data\superstore.db
# C:\Users\juhip\OneDrive\Desktop\python folder\apexplanet-data-analytics\data\Sample - Superstore.csv
# C:\Users\juhip\OneDrive\Desktop\python folder\apexplanet-data-analytics\data\superstore_cleaned.csv

# %%
import pandas as pd
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilename(
    title="Select Sample - Superstore.csv",
    filetypes=[("CSV files", "*.csv")]
)

print("Selected file:", file_path)

df = pd.read_csv(file_path, encoding="latin1")

print("Dataset loaded successfully!")
# Out:
# Selected file:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 15
#      11 )
#      12
#      13 print("Selected file:", file_path)
#      14
# ---> 15 df = pd.read_csv(file_path, encoding="latin1")
#      16
#      17 print("Dataset loaded successfully!")
#
# ...
